# %%
# !pip install spotipy
# Out:
# Requirement already satisfied: spotipy in ./venv/lib/python3.13/site-packages (2.25.1)
# Requirement already satisfied: redis>=3.5.3 in ./venv/lib/python3.13/site-packages (from spotipy) (6.2.0)
# Requirement already satisfied: requests>=2.25.0 in ./venv/lib/python3.13/site-packages (from spotipy) (2.32.4)
# Requirement already satisfied: urllib3>=1.26.0 in ./venv/lib/python3.13/site-packages (from spotipy) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests>=2.25.0->spotipy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.13/site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.13/site-packages (from requests>=2.25.0->spotipy) (2025.6.15)

# %%
pip install --upgrade spotipy
# Out:
# Requirement already satisfied: spotipy in ./venv/lib/python3.13/site-packages (2.25.1)
# Requirement already satisfied: redis>=3.5.3 in ./venv/lib/python3.13/site-packages (from spotipy) (6.2.0)
# Requirement already satisfied: requests>=2.25.0 in ./venv/lib/python3.13/site-packages (from spotipy) (2.32.4)
# Requirement already satisfied: urllib3>=1.26.0 in ./venv/lib/python3.13/site-packages (from spotipy) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./venv/lib/python3.13/site-packages (from requests>=2.25.0->spotipy) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.13/site-packages (from requests>=2.25.0->spotipy) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.13/site-packages (from requests>=2.25.0->spotipy) (2025.6.15)
# Note: you may need to restart the kernel to use updated packages.

# %%
from spotipy.oauth2 import SpotifyOAuth

import spotipy

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id="7c42f1649a224b6aa1ab450f164c0fa9",
    client_secret="fdad80deac184a0f9154b1ab46f369a6",
    redirect_uri="http://127.0.0.1:8889/callback",
    scope="playlist-read-private"
))

# %% [raw]
# playlist_link = "https://open.spotify.com/playlist/7rBjBuIpTiE0UOqHqCtupz"
# playlist_id = playlist_link.split("/")[-1].split("?")[0]

# %%
data = sp.playlist_items(playlist_id)

# %%
data['items']
# Out:
# [{'added_at': '2019-06-16T02:55:39Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['KR'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['KR'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/21dd5QyItuoqvPkViQXlKf',
#     'id': '21dd5QyItuoqvPkViQXlKf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d8315d631ef620fbbff03d5b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d8315d631ef620fbbff03d5b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d8315d631ef620fbbff03d5b',
#       'width': 64}],
#     'name': 'You Need To Calm Down',
#     'release_date': '2019-06-14',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:21dd5QyItuoqvPkViQXlKf',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/21dd5QyItuoqvPkViQXlKf'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 171386,
#    'external_ids': {'isrc': 'USUG11901470'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/29fRTIKsJhLUJoldM89GZS'},
#    'href': 'https://api.spotify.com/v1/tracks/29fRTIKsJhLUJoldM89GZS',
#    'id': '29fRTIKsJhLUJoldM89GZS',
#    'name': 'You Need To Calm Down',
#    'popularity': 18,
#    'uri': 'spotify:track:29fRTIKsJhLUJoldM89GZS',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-07-18T03:25:29Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/2ZaX1FdZCwchXl1QZiD4O4',
#     'id': '2ZaX1FdZCwchXl1QZiD4O4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6095c382c2853667c1623eb',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6095c382c2853667c1623eb',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6095c382c2853667c1623eb',
#       'width': 64}],
#     'name': 'Señorita',
#     'release_date': '2019-06-21',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:2ZaX1FdZCwchXl1QZiD4O4',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#       'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#       'id': '7n2wHs1TKAczGzO7Dd2rGr',
#       'name': 'Shawn Mendes',
#       'type': 'artist',
#       'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4nDoRrQiYLoBzwC5BhVJzF'},
#       'href': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF',
#       'id': '4nDoRrQiYLoBzwC5BhVJzF',
#       'name': 'Camila Cabello',
#       'type': 'artist',
#       'uri': 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2ZaX1FdZCwchXl1QZiD4O4'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#      'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#      'id': '7n2wHs1TKAczGzO7Dd2rGr',
#      'name': 'Shawn Mendes',
#      'type': 'artist',
#      'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4nDoRrQiYLoBzwC5BhVJzF'},
#      'href': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF',
#      'id': '4nDoRrQiYLoBzwC5BhVJzF',
#      'name': 'Camila Cabello',
#      'type': 'artist',
#      'uri': 'spotify:artist:4nDoRrQiYLoBzwC5BhVJzF'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 190960,
#    'external_ids': {'isrc': 'USUM71911283'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0TK2YIli7K1leLovkQiNik'},
#    'href': 'https://api.spotify.com/v1/tracks/0TK2YIli7K1leLovkQiNik',
#    'id': '0TK2YIli7K1leLovkQiNik',
#    'name': 'Señorita',
#    'popularity': 82,
#    'uri': 'spotify:track:0TK2YIli7K1leLovkQiNik',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-07-18T03:25:41Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/3KjXg0MDej2pG9fv6I22lT',
#     'id': '3KjXg0MDej2pG9fv6I22lT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739bea3b79b95f86d1b66ac960',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029bea3b79b95f86d1b66ac960',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519bea3b79b95f86d1b66ac960',
#       'width': 64}],
#     'name': 'Never Really Over',
#     'release_date': '2019-05-31',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:3KjXg0MDej2pG9fv6I22lT',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#       'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#       'id': '6jJ0s89eD6GaHleKKya26X',
#       'name': 'Katy Perry',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3KjXg0MDej2pG9fv6I22lT'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jJ0s89eD6GaHleKKya26X'},
#      'href': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X',
#      'id': '6jJ0s89eD6GaHleKKya26X',
#      'name': 'Katy Perry',
#      'type': 'artist',
#      'uri': 'spotify:artist:6jJ0s89eD6GaHleKKya26X'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 223523,
#    'external_ids': {'isrc': 'USUM71901873'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5PYQUBXc7NYeI1obMKSJK0'},
#    'href': 'https://api.spotify.com/v1/tracks/5PYQUBXc7NYeI1obMKSJK0',
#    'id': '5PYQUBXc7NYeI1obMKSJK0',
#    'name': 'Never Really Over',
#    'popularity': 71,
#    'uri': 'spotify:track:5PYQUBXc7NYeI1obMKSJK0',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-09-22T04:15:31Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/0S9QJQiRmG9JYYfJfKqhDF',
#     'id': '0S9QJQiRmG9JYYfJfKqhDF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738a24ed638eedd60514a789ef',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028a24ed638eedd60514a789ef',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518a24ed638eedd60514a789ef',
#       'width': 64}],
#     'name': 'Illuminate (Deluxe)',
#     'release_date': '2016-09-23',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:0S9QJQiRmG9JYYfJfKqhDF',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#       'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#       'id': '7n2wHs1TKAczGzO7Dd2rGr',
#       'name': 'Shawn Mendes',
#       'type': 'artist',
#       'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0S9QJQiRmG9JYYfJfKqhDF'},
#     'total_tracks': 15},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n2wHs1TKAczGzO7Dd2rGr'},
#      'href': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr',
#      'id': '7n2wHs1TKAczGzO7Dd2rGr',
#      'name': 'Shawn Mendes',
#      'type': 'artist',
#      'uri': 'spotify:artist:7n2wHs1TKAczGzO7Dd2rGr'}],
#    'disc_number': 1,
#    'track_number': 3,
#    'duration_ms': 187973,
#    'external_ids': {'isrc': 'USUM71604711'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/76t5B0ttSAje5KHmQbv88t'},
#    'href': 'https://api.spotify.com/v1/tracks/76t5B0ttSAje5KHmQbv88t',
#    'id': '76t5B0ttSAje5KHmQbv88t',
#    'name': 'Treat You Better',
#    'popularity': 1,
#    'uri': 'spotify:track:76t5B0ttSAje5KHmQbv88t',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-09-22T04:15:35Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'SE',
#     'CH',
#     'TW',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'LA',
#     'MO',
#     'MR',
#     'NP',
#     'RW',
#     'TG',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'SE',
#      'CH',
#      'TW',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'LA',
#      'MO',
#      'MR',
#      'NP',
#      'RW',
#      'TG',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/4vaaL8cnVy5KBJqbEPD8RF',
#     'id': '4vaaL8cnVy5KBJqbEPD8RF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27388104647763f4c2c554f2301',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0288104647763f4c2c554f2301',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485188104647763f4c2c554f2301',
#       'width': 64}],
#     'name': 'Sugar & Brownies',
#     'release_date': '2019-04-05',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:4vaaL8cnVy5KBJqbEPD8RF',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1psakk7GVUl85AnTEvwtk2'},
#       'href': 'https://api.spotify.com/v1/artists/1psakk7GVUl85AnTEvwtk2',
#       'id': '1psakk7GVUl85AnTEvwtk2',
#       'name': 'DHARIA',
#       'type': 'artist',
#       'uri': 'spotify:artist:1psakk7GVUl85AnTEvwtk2'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4vaaL8cnVy5KBJqbEPD8RF'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1psakk7GVUl85AnTEvwtk2'},
#      'href': 'https://api.spotify.com/v1/artists/1psakk7GVUl85AnTEvwtk2',
#      'id': '1psakk7GVUl85AnTEvwtk2',
#      'name': 'DHARIA',
#      'type': 'artist',
#      'uri': 'spotify:artist:1psakk7GVUl85AnTEvwtk2'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 197836,
#    'external_ids': {'isrc': 'FR96X1871858'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4CAEINtapxGNYyjjJ1AKOA'},
#    'href': 'https://api.spotify.com/v1/tracks/4CAEINtapxGNYyjjJ1AKOA',
#    'id': '4CAEINtapxGNYyjjJ1AKOA',
#    'name': 'Sugar & Brownies',
#    'popularity': 67,
#    'uri': 'spotify:track:4CAEINtapxGNYyjjJ1AKOA',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-09-22T04:16:18Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'compilation',
#     'href': 'https://api.spotify.com/v1/albums/2koMSm4dddvhxLzZyN2aEE',
#     'id': '2koMSm4dddvhxLzZyN2aEE',
#     'images': [],
#     'name': '',
#     'release_date': '0000',
#     'release_date_precision': 'year',
#     'uri': 'spotify:album:2koMSm4dddvhxLzZyN2aEE',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2koMSm4dddvhxLzZyN2aEE'},
#     'total_tracks': 7},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': '',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 0,
#    'external_ids': {},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4t1DkxexoMbIHfSHS4Uiyr'},
#    'href': 'https://api.spotify.com/v1/tracks/4t1DkxexoMbIHfSHS4Uiyr',
#    'id': '4t1DkxexoMbIHfSHS4Uiyr',
#    'name': '',
#    'popularity': 0,
#    'uri': 'spotify:track:4t1DkxexoMbIHfSHS4Uiyr',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-09-22T04:21:53Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/3i2JOacHRxFzMvvbNtaTjL',
#     'id': '3i2JOacHRxFzMvvbNtaTjL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f6a19b82beb8a4d5af2071a9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f6a19b82beb8a4d5af2071a9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f6a19b82beb8a4d5af2071a9',
#       'width': 64}],
#     'name': 'Somebody (Remixes)',
#     'release_date': '2018-04-06',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:3i2JOacHRxFzMvvbNtaTjL',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#       'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#       'id': '69GGBxA162lTqCwzJG5jLp',
#       'name': 'The Chainsmokers',
#       'type': 'artist',
#       'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/76yeOnINtQSXyoEHbkYmtY'},
#       'href': 'https://api.spotify.com/v1/artists/76yeOnINtQSXyoEHbkYmtY',
#       'id': '76yeOnINtQSXyoEHbkYmtY',
#       'name': 'Drew Love',
#       'type': 'artist',
#       'uri': 'spotify:artist:76yeOnINtQSXyoEHbkYmtY'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3i2JOacHRxFzMvvbNtaTjL'},
#     'total_tracks': 6},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/69GGBxA162lTqCwzJG5jLp'},
#      'href': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp',
#      'id': '69GGBxA162lTqCwzJG5jLp',
#      'name': 'The Chainsmokers',
#      'type': 'artist',
#      'uri': 'spotify:artist:69GGBxA162lTqCwzJG5jLp'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/76yeOnINtQSXyoEHbkYmtY'},
#      'href': 'https://api.spotify.com/v1/artists/76yeOnINtQSXyoEHbkYmtY',
#      'id': '76yeOnINtQSXyoEHbkYmtY',
#      'name': 'Drew Love',
#      'type': 'artist',
#      'uri': 'spotify:artist:76yeOnINtQSXyoEHbkYmtY'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1xLhhhPXc6NUNxUXDG5Psb'},
#      'href': 'https://api.spotify.com/v1/artists/1xLhhhPXc6NUNxUXDG5Psb',
#      'id': '1xLhhhPXc6NUNxUXDG5Psb',
#      'name': 'Ruhde',
#      'type': 'artist',
#      'uri': 'spotify:artist:1xLhhhPXc6NUNxUXDG5Psb'}],
#    'disc_number': 1,
#    'track_number': 6,
#    'duration_ms': 219053,
#    'external_ids': {'isrc': 'USQX91801153'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/42gkSeUtmr7gwxT62BJGiZ'},
#    'href': 'https://api.spotify.com/v1/tracks/42gkSeUtmr7gwxT62BJGiZ',
#    'id': '42gkSeUtmr7gwxT62BJGiZ',
#    'name': 'Somebody - Ruhde Remix',
#    'popularity': 35,
#    'uri': 'spotify:track:42gkSeUtmr7gwxT62BJGiZ',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-09-22T04:25:11Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/33pt9HBdGlAbRGBHQgsZsU',
#     'id': '33pt9HBdGlAbRGBHQgsZsU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735675e83f707f1d7271e5cf8a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025675e83f707f1d7271e5cf8a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515675e83f707f1d7271e5cf8a',
#       'width': 64}],
#     'name': 'Evolve',
#     'release_date': '2017-06-23',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:33pt9HBdGlAbRGBHQgsZsU',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/33pt9HBdGlAbRGBHQgsZsU'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#      'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#      'id': '53XhwfbYqKCa1cC15pYq2q',
#      'name': 'Imagine Dragons',
#      'type': 'artist',
#      'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#    'disc_number': 1,
#    'track_number': 4,
#    'duration_ms': 204346,
#    'external_ids': {'isrc': 'USUM71700626'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0pqnGHJpmpxLKifKRmU6WP'},
#    'href': 'https://api.spotify.com/v1/tracks/0pqnGHJpmpxLKifKRmU6WP',
#    'id': '0pqnGHJpmpxLKifKRmU6WP',
#    'name': 'Believer',
#    'popularity': 91,
#    'uri': 'spotify:track:0pqnGHJpmpxLKifKRmU6WP',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-09-22T04:25:57Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': [],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': [],
#     'type': 'album',
#     'album_type': 'album',
#     'href': 'https://api.spotify.com/v1/albums/0kjXSwSLVipUi4lSEeF0yl',
#     'id': '0kjXSwSLVipUi4lSEeF0yl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734566e671e5c947cba3a38436',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024566e671e5c947cba3a38436',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514566e671e5c947cba3a38436',
#       'width': 64}],
#     'name': 'All The Little Lights',
#     'release_date': '2012',
#     'release_date_precision': 'year',
#     'uri': 'spotify:album:0kjXSwSLVipUi4lSEeF0yl',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0gadJ2b9A4SKsB1RFkBb66'},
#       'href': 'https://api.spotify.com/v1/artists/0gadJ2b9A4SKsB1RFkBb66',
#       'id': '0gadJ2b9A4SKsB1RFkBb66',
#       'name': 'Passenger',
#       'type': 'artist',
#       'uri': 'spotify:artist:0gadJ2b9A4SKsB1RFkBb66'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0kjXSwSLVipUi4lSEeF0yl'},
#     'total_tracks': 12},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0gadJ2b9A4SKsB1RFkBb66'},
#      'href': 'https://api.spotify.com/v1/artists/0gadJ2b9A4SKsB1RFkBb66',
#      'id': '0gadJ2b9A4SKsB1RFkBb66',
#      'name': 'Passenger',
#      'type': 'artist',
#      'uri': 'spotify:artist:0gadJ2b9A4SKsB1RFkBb66'}],
#    'disc_number': 1,
#    'track_number': 2,
#    'duration_ms': 252866,
#    'external_ids': {'isrc': 'GBMQN1100004'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2jyjhRf6DVbMPU5zxagN2h'},
#    'href': 'https://api.spotify.com/v1/tracks/2jyjhRf6DVbMPU5zxagN2h',
#    'id': '2jyjhRf6DVbMPU5zxagN2h',
#    'name': 'Let Her Go',
#    'popularity': 1,
#    'uri': 'spotify:track:2jyjhRf6DVbMPU5zxagN2h',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-09-22T04:27:55Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AE',
#     'AR',
#     'AT',
#     'AU',
#     'BA',
#     'BD',
#     'BE',
#     'BG',
#     'BH',
#     'BO',
#     'BR',
#     'BY',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GN',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IQ',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KR',
#     'KW',
#     'KZ',
#     'LB',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'ME',
#     'MK',
#     'MT',
#     'MU',
#     'MX',
#     'MY',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SN',
#     'SV',
#     'TH',
#     'TJ',
#     'TN',
#     'TR',
#     'TW',
#     'TZ',
#     'UA',
#     'VE',
#     'XK',
#     'ZA'],
#    'explicit': False,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AE',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BD',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GN',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KR',
#      'KW',
#      'KZ',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MU',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TJ',
#      'TN',
#      'TR',
#      'TW',
#      'TZ',
#      'UA',
#      'VE',
#      'XK',
#      'ZA'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/5SXTscj33KnBUpDyIsZTEf',
#     'id': '5SXTscj33KnBUpDyIsZTEf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273aac3b3863e8f7a43a9b65a19',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02aac3b3863e8f7a43a9b65a19',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851aac3b3863e8f7a43a9b65a19',
#       'width': 64}],
#     'name': 'Tokyo Drift (Fast & Furious)',
#     'release_date': '2006-01-01',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:5SXTscj33KnBUpDyIsZTEf',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7HBai5xymOxIWoMWvWshe1'},
#       'href': 'https://api.spotify.com/v1/artists/7HBai5xymOxIWoMWvWshe1',
#       'id': '7HBai5xymOxIWoMWvWshe1',
#       'name': 'Teriyaki Boyz',
#       'type': 'artist',
#       'uri': 'spotify:artist:7HBai5xymOxIWoMWvWshe1'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5SXTscj33KnBUpDyIsZTEf'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7HBai5xymOxIWoMWvWshe1'},
#      'href': 'https://api.spotify.com/v1/artists/7HBai5xymOxIWoMWvWshe1',
#      'id': '7HBai5xymOxIWoMWvWshe1',
#      'name': 'Teriyaki Boyz',
#      'type': 'artist',
#      'uri': 'spotify:artist:7HBai5xymOxIWoMWvWshe1'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 255946,
#    'external_ids': {'isrc': 'USUG10600159'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0upFohXrGxIIAjyaJmCkMU'},
#    'href': 'https://api.spotify.com/v1/tracks/0upFohXrGxIIAjyaJmCkMU',
#    'id': '0upFohXrGxIIAjyaJmCkMU',
#    'name': 'Tokyo Drift (Fast & Furious) - From "The Fast And The Furious: Tokyo Drift" Soundtrack',
#    'popularity': 76,
#    'uri': 'spotify:track:0upFohXrGxIIAjyaJmCkMU',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-09-22T04:29:35Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
# ...
#       'id': '1tqysapcCh1lWEAc9dIFpa',
#       'name': 'Jubin Nautiyal',
#       'type': 'artist',
#       'uri': 'spotify:artist:1tqysapcCh1lWEAc9dIFpa'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1sVmXkzX2ukc6QvasrDBES'},
#       'href': 'https://api.spotify.com/v1/artists/1sVmXkzX2ukc6QvasrDBES',
#       'id': '1sVmXkzX2ukc6QvasrDBES',
#       'name': 'Asees Kaur',
#       'type': 'artist',
#       'uri': 'spotify:artist:1sVmXkzX2ukc6QvasrDBES'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2DKSZvMj7Da6rzNVPMgREj'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4f7KfxeHq9BiylGmyXepGt'},
#      'href': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt',
#      'id': '4f7KfxeHq9BiylGmyXepGt',
#      'name': 'Tanishk Bagchi',
#      'type': 'artist',
#      'uri': 'spotify:artist:4f7KfxeHq9BiylGmyXepGt'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1tqysapcCh1lWEAc9dIFpa'},
#      'href': 'https://api.spotify.com/v1/artists/1tqysapcCh1lWEAc9dIFpa',
#      'id': '1tqysapcCh1lWEAc9dIFpa',
#      'name': 'Jubin Nautiyal',
#      'type': 'artist',
#      'uri': 'spotify:artist:1tqysapcCh1lWEAc9dIFpa'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1sVmXkzX2ukc6QvasrDBES'},
#      'href': 'https://api.spotify.com/v1/artists/1sVmXkzX2ukc6QvasrDBES',
#      'id': '1sVmXkzX2ukc6QvasrDBES',
#      'name': 'Asees Kaur',
#      'type': 'artist',
#      'uri': 'spotify:artist:1sVmXkzX2ukc6QvasrDBES'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 230292,
#    'external_ids': {'isrc': 'INS172102667'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2rOnSn2piaqLAlYjtfUBlY'},
#    'href': 'https://api.spotify.com/v1/tracks/2rOnSn2piaqLAlYjtfUBlY',
#    'id': '2rOnSn2piaqLAlYjtfUBlY',
#    'name': 'Raataan Lambiyan (From "Shershaah")',
#    'popularity': 75,
#    'uri': 'spotify:track:2rOnSn2piaqLAlYjtfUBlY',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-29T08:31:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': True,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/0boA7GUGSxOMWwdnnTR0yI',
#     'id': '0boA7GUGSxOMWwdnnTR0yI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27378023ccce25da7ca56a479e9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0278023ccce25da7ca56a479e9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485178023ccce25da7ca56a479e9',
#       'width': 64}],
#     'name': 'Into Your Arms (feat. Ava Max)',
#     'release_date': '2018-06-08',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:0boA7GUGSxOMWwdnnTR0yI',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ghnxpW47ojtLHHyTLdxdY'},
#       'href': 'https://api.spotify.com/v1/artists/5ghnxpW47ojtLHHyTLdxdY',
#       'id': '5ghnxpW47ojtLHHyTLdxdY',
#       'name': 'Witt Lowry',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ghnxpW47ojtLHHyTLdxdY'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4npEfmQ6YuiwW1GpUmaq3F'},
#       'href': 'https://api.spotify.com/v1/artists/4npEfmQ6YuiwW1GpUmaq3F',
#       'id': '4npEfmQ6YuiwW1GpUmaq3F',
#       'name': 'Ava Max',
#       'type': 'artist',
#       'uri': 'spotify:artist:4npEfmQ6YuiwW1GpUmaq3F'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0boA7GUGSxOMWwdnnTR0yI'},
#     'total_tracks': 3},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ghnxpW47ojtLHHyTLdxdY'},
#      'href': 'https://api.spotify.com/v1/artists/5ghnxpW47ojtLHHyTLdxdY',
#      'id': '5ghnxpW47ojtLHHyTLdxdY',
#      'name': 'Witt Lowry',
#      'type': 'artist',
#      'uri': 'spotify:artist:5ghnxpW47ojtLHHyTLdxdY'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4npEfmQ6YuiwW1GpUmaq3F'},
#      'href': 'https://api.spotify.com/v1/artists/4npEfmQ6YuiwW1GpUmaq3F',
#      'id': '4npEfmQ6YuiwW1GpUmaq3F',
#      'name': 'Ava Max',
#      'type': 'artist',
#      'uri': 'spotify:artist:4npEfmQ6YuiwW1GpUmaq3F'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 186022,
#    'external_ids': {'isrc': 'USAT21802013'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0b11D9D0hMOYCIMN3OKreM'},
#    'href': 'https://api.spotify.com/v1/tracks/0b11D9D0hMOYCIMN3OKreM',
#    'id': '0b11D9D0hMOYCIMN3OKreM',
#    'name': 'Into Your Arms (feat. Ava Max)',
#    'popularity': 76,
#    'uri': 'spotify:track:0b11D9D0hMOYCIMN3OKreM',
#    'is_local': False},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-10-29T08:32:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#    'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#    'id': '316qtia7vgfths2tkig4q727ywd4',
#    'type': 'user',
#    'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'explicit': True,
#    'type': 'track',
#    'episode': False,
#    'track': True,
#    'album': {'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'type': 'album',
#     'album_type': 'single',
#     'href': 'https://api.spotify.com/v1/albums/4QLAtpLNUsHEYrcHXmMIZZ',
#     'id': '4QLAtpLNUsHEYrcHXmMIZZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27341e31d6ea1d493dd77933ee5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0241e31d6ea1d493dd77933ee5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485141e31d6ea1d493dd77933ee5',
#       'width': 64}],
#     'name': 'STAY (with Justin Bieber)',
#     'release_date': '2021-07-09',
#     'release_date_precision': 'day',
#     'uri': 'spotify:album:4QLAtpLNUsHEYrcHXmMIZZ',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tIP7SsRs7vjIcLrU85W8J'},
#       'href': 'https://api.spotify.com/v1/artists/2tIP7SsRs7vjIcLrU85W8J',
#       'id': '2tIP7SsRs7vjIcLrU85W8J',
#       'name': 'The Kid LAROI',
#       'type': 'artist',
#       'uri': 'spotify:artist:2tIP7SsRs7vjIcLrU85W8J'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4QLAtpLNUsHEYrcHXmMIZZ'},
#     'total_tracks': 1},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tIP7SsRs7vjIcLrU85W8J'},
#      'href': 'https://api.spotify.com/v1/artists/2tIP7SsRs7vjIcLrU85W8J',
#      'id': '2tIP7SsRs7vjIcLrU85W8J',
#      'name': 'The Kid LAROI',
#      'type': 'artist',
#      'uri': 'spotify:artist:2tIP7SsRs7vjIcLrU85W8J'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#      'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#      'id': '1uNFoZAHBGtllmzznpCI3s',
#      'name': 'Justin Bieber',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#    'disc_number': 1,
#    'track_number': 1,
#    'duration_ms': 141805,
#    'external_ids': {'isrc': 'USSM12103949'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5HCyWlXZPP0y6Gqq8TgA20'},
#    'href': 'https://api.spotify.com/v1/tracks/5HCyWlXZPP0y6Gqq8TgA20',
#    'id': '5HCyWlXZPP0y6Gqq8TgA20',
#    'name': 'STAY (with Justin Bieber)',
#    'popularity': 84,
#    'uri': 'spotify:track:5HCyWlXZPP0y6Gqq8TgA20',
#    'is_local': False},
#   'video_thumbnail': {'url': None}}]

# %%
data['items'][0]['track']['album']['id']
# Out:
# '21dd5QyItuoqvPkViQXlKf'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'You Need To Calm Down'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2019-06-14'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/21dd5QyItuoqvPkViQXlKf'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '21dd5QyItuoqvPkViQXlKf',
#   'name': 'You Need To Calm Down',
#   'release_date': '2019-06-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/21dd5QyItuoqvPkViQXlKf'},
#  {'album_id': '2ZaX1FdZCwchXl1QZiD4O4',
#   'name': 'Señorita',
#   'release_date': '2019-06-21',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2ZaX1FdZCwchXl1QZiD4O4'},
#  {'album_id': '3KjXg0MDej2pG9fv6I22lT',
#   'name': 'Never Really Over',
#   'release_date': '2019-05-31',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3KjXg0MDej2pG9fv6I22lT'},
#  {'album_id': '0S9QJQiRmG9JYYfJfKqhDF',
#   'name': 'Illuminate (Deluxe)',
#   'release_date': '2016-09-23',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/0S9QJQiRmG9JYYfJfKqhDF'},
#  {'album_id': '4vaaL8cnVy5KBJqbEPD8RF',
#   'name': 'Sugar & Brownies',
#   'release_date': '2019-04-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4vaaL8cnVy5KBJqbEPD8RF'},
#  {'album_id': '2koMSm4dddvhxLzZyN2aEE',
#   'name': '',
#   'release_date': '0000',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/2koMSm4dddvhxLzZyN2aEE'},
#  {'album_id': '3i2JOacHRxFzMvvbNtaTjL',
#   'name': 'Somebody (Remixes)',
#   'release_date': '2018-04-06',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/3i2JOacHRxFzMvvbNtaTjL'},
#  {'album_id': '33pt9HBdGlAbRGBHQgsZsU',
#   'name': 'Evolve',
#   'release_date': '2017-06-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/33pt9HBdGlAbRGBHQgsZsU'},
#  {'album_id': '0kjXSwSLVipUi4lSEeF0yl',
#   'name': 'All The Little Lights',
#   'release_date': '2012',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/0kjXSwSLVipUi4lSEeF0yl'},
#  {'album_id': '5SXTscj33KnBUpDyIsZTEf',
#   'name': 'Tokyo Drift (Fast & Furious)',
#   'release_date': '2006-01-01',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5SXTscj33KnBUpDyIsZTEf'},
#  {'album_id': '3R0yYY0gYCSg3jwcd5t3PC',
#   'name': 'Red Swan - TV Edit -',
#   'release_date': '2018-07-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3R0yYY0gYCSg3jwcd5t3PC'},
#  {'album_id': '3ur0aoe8AKjK3iofS1erhZ',
#   'name': 'Unravel',
#   'release_date': '2014-07-23',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/3ur0aoe8AKjK3iofS1erhZ'},
#  {'album_id': '1YdXQgntClL3BhIXB0xpgs',
#   'name': 'All of Me',
#   'release_date': '2013-08-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1YdXQgntClL3BhIXB0xpgs'},
#  {'album_id': '1rzDtYMpZDhRgKNigB467r',
#   'name': 'Night Visions (Deluxe)',
#   'release_date': '2012-09-04',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1rzDtYMpZDhRgKNigB467r'},
#  {'album_id': '5uRN1MDHR5kvQKQJZxSSKY',
#   'name': 'Khud Se Zyada',
#   'release_date': '2019-08-21',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5uRN1MDHR5kvQKQJZxSSKY'},
#  {'album_id': '2fLkonSk9cVovvnRKKYtk5',
#   'name': 'Cradles',
#   'release_date': '2019-01-04',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2fLkonSk9cVovvnRKKYtk5'},
#  {'album_id': '3nR9B40hYLKLcR0Eph3Goc',
#   'name': 'Memories',
#   'release_date': '2019-09-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3nR9B40hYLKLcR0Eph3Goc'},
#  {'album_id': '1AvXa8xFEXtR3hb4bgihIK',
#   'name': 'MAP OF THE SOUL : PERSONA',
#   'release_date': '2019-04-12',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/1AvXa8xFEXtR3hb4bgihIK'},
#  {'album_id': '35s58BRTGAEWztPo9WqCIs',
#   'name': 'Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)',
#   'release_date': '2018-12-14',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/35s58BRTGAEWztPo9WqCIs'},
#  {'album_id': '2XPlNDlpuJyEBRnZnbZcut',
#   'name': 'Bella Ciao',
#   'release_date': '2018-08-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2XPlNDlpuJyEBRnZnbZcut'},
#  {'album_id': '3JfSxDfmwS5OeHPwLSkrfr',
#   'name': 'Origins (Deluxe)',
#   'release_date': '2018-11-09',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/3JfSxDfmwS5OeHPwLSkrfr'},
#  {'album_id': '7IzpJkWQqgz1BTutQvSitX',
#   'name': 'Something Just Like This',
#   'release_date': '2017-02-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7IzpJkWQqgz1BTutQvSitX'},
#  {'album_id': '700MviIgFKNTldTXmOAFOr',
#   'name': 'Alone, Pt. II',
#   'release_date': '2019-12-27',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/700MviIgFKNTldTXmOAFOr'},
#  {'album_id': '38J3178QtYOM7qQZLjQiIs',
#   'name': 'Chidiya',
#   'release_date': '2019-12-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/38J3178QtYOM7qQZLjQiIs'},
#  {'album_id': '5zrZPXoYsu772sB3CwVuxr',
#   'name': 'Dil Bechara (Original Motion Picture Soundtrack)',
#   'release_date': '2020-07-10',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/5zrZPXoYsu772sB3CwVuxr'},
#  {'album_id': '557QFyhyOXzJ39kXC0tLSv',
#   'name': 'Young Shahrukh',
#   'release_date': '2020-05-22',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/557QFyhyOXzJ39kXC0tLSv'},
#  {'album_id': '5r9bLIpSpE5ddweubUjw0t',
#   'name': 'Liggi',
#   'release_date': '2019-12-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5r9bLIpSpE5ddweubUjw0t'},
#  {'album_id': '4rO2r1Mv1vbHPJbP1DF6rO',
#   'name': 'Firse Machayenge (Remix)',
#   'release_date': '2020-06-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4rO2r1Mv1vbHPJbP1DF6rO'},
#  {'album_id': '6IXfWhC7omotM4lt0ROmEr',
#   'name': 'Love Aaj Kal (Original Motion Picture Soundtrack)',
#   'release_date': '2020-02-14',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/6IXfWhC7omotM4lt0ROmEr'},
#  {'album_id': '4MHHajvRTUHItDsvfdIC8B',
#   'name': 'ily (i love you baby) (feat. Emilee)',
#   'release_date': '2019-11-26',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4MHHajvRTUHItDsvfdIC8B'},
#  {'album_id': '2p9gK2BcdrloHNJwarc9gc',
#   'name': 'death bed (coffee for your head)',
#   'release_date': '2020-02-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2p9gK2BcdrloHNJwarc9gc'},
#  {'album_id': '31IDBea3eEs57a0joX6TjN',
#   'name': 'Dance Monkey',
#   'release_date': '2019-05-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/31IDBea3eEs57a0joX6TjN'},
#  {'album_id': '7lF34sP6HtRAL7VEMvYHff',
#   'name': '',
#   'release_date': '0000',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/7lF34sP6HtRAL7VEMvYHff'},
#  {'album_id': '1XMw3pBrYeXzNXZXc84DNw',
#   'name': 'Savage Love (Laxed - Siren Beat)',
#   'release_date': '2020-06-11',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1XMw3pBrYeXzNXZXc84DNw'},
#  {'album_id': '6trNtQUgC8cgbWcqoMYkOR',
#   'name': 'beerbongs & bentleys',
#   'release_date': '2018-04-27',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6trNtQUgC8cgbWcqoMYkOR'},
#  {'album_id': '6K4chJALBBMYmXjwgvqahx',
#   'name': 'Dynamite (DayTime Version)',
#   'release_date': '2020-08-28',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/6K4chJALBBMYmXjwgvqahx'},
#  {'album_id': '5O6izFQ2veRaZOcQSyOi4o',
#   'name': 'Savage Love (Laxed - Siren Beat) [BTS Remix]',
#   'release_date': '2020-10-02',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/5O6izFQ2veRaZOcQSyOi4o'},
#  {'album_id': '4yP0hdKOZPNshxUOjY0cZj',
#   'name': 'After Hours',
#   'release_date': '2020-03-20',
#   'total_tracks': 14,
#   'url': 'https://open.spotify.com/album/4yP0hdKOZPNshxUOjY0cZj'},
#  {'album_id': '1hUQqz8V92YePE0lIizW3n',
#   'name': 'Cry Baby (Deluxe Edition)',
#   'release_date': '2015-08-14',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/1hUQqz8V92YePE0lIizW3n'},
#  {'album_id': '0bRAth39i98n7qrxubZ00K',
#   'name': 'Jerusalema',
#   'release_date': '2020-01-24',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/0bRAth39i98n7qrxubZ00K'},
#  {'album_id': '01gwy6CbJo0sNcKxzlZ9om',
#   'name': '',
#   'release_date': '0000',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/01gwy6CbJo0sNcKxzlZ9om'},
#  {'album_id': '77dwEKk1JI2JN9L5tg8d7t',
#   'name': 'Teri Aankhon Mein',
#   'release_date': '2020-10-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/77dwEKk1JI2JN9L5tg8d7t'},
#  {'album_id': '0NJUegUl6z7iKZkXsxSzYD',
#   'name': 'Dance Monkey',
#   'release_date': '2019-10-30',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/0NJUegUl6z7iKZkXsxSzYD'},
#  {'album_id': '2H2vZ4uw4gteyA8pBWLvwI',
#   'name': 'Let Me Down Slowly (Ibara Remix)',
#   'release_date': '2019-03-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2H2vZ4uw4gteyA8pBWLvwI'},
#  {'album_id': '3nzuGtN3nXARvvecier4K0',
#   'name': 'Different World',
#   'release_date': '2018-12-14',
#   'total_tracks': 15,
#   'url': 'https://open.spotify.com/album/3nzuGtN3nXARvvecier4K0'},
#  {'album_id': '1Ag9EPbzibwzz0S0WpgX3v',
#   'name': 'Hawái (Remix)',
#   'release_date': '2020-11-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1Ag9EPbzibwzz0S0WpgX3v'},
#  {'album_id': '2qehskW9lYGWfYb0xPZkrS',
#   'name': 'BE',
#   'release_date': '2020-11-20',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/2qehskW9lYGWfYb0xPZkrS'},
#  {'album_id': '7veJEEW836HtKZG9Admr3z',
#   'name': 'Mirchi',
#   'release_date': '2020-10-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7veJEEW836HtKZG9Admr3z'},
#  {'album_id': '6gPsylHkKTVVNLXRN9RLYy',
#   'name': 'Taaron Ke Shehar',
#   'release_date': '2020-09-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6gPsylHkKTVVNLXRN9RLYy'},
#  {'album_id': '7sDecy4TUrJpkPnOmAiVKn',
#   'name': 'Sage',
#   'release_date': '2019-06-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7sDecy4TUrJpkPnOmAiVKn'},
#  {'album_id': '33GSYbSHgDXzy6RsxNyR3O',
#   'name': 'Chalo Chalein',
#   'release_date': '2019-12-23',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/33GSYbSHgDXzy6RsxNyR3O'},
#  {'album_id': '3xmweHio8FukX8ALVFuujZ',
#   'name': 'Thandi Hawa',
#   'release_date': '2020-04-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3xmweHio8FukX8ALVFuujZ'},
#  {'album_id': '5Wm1nhxZqx7i0Hp6ZBqe9T',
#   'name': 'Love Forever With Arijit Singh',
#   'release_date': '2017-06-07',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/5Wm1nhxZqx7i0Hp6ZBqe9T'},
#  {'album_id': '3HJpyQVnGvbQcwk3uKeMtz',
#   'name': 'Dooriyan (feat. Kaprila)',
#   'release_date': '2020-01-13',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3HJpyQVnGvbQcwk3uKeMtz'},
#  {'album_id': '3fyH2rJzSONq5x4fEZQcJU',
#   'name': 'Wishlist (feat. Kaprila)',
#   'release_date': '2020-03-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3fyH2rJzSONq5x4fEZQcJU'},
#  {'album_id': '6qc16gUvik05h9ztn3OwHn',
#   'name': 'Filhall',
#   'release_date': '2019-11-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/6qc16gUvik05h9ztn3OwHn'},
#  {'album_id': '0xPcW40GWPqYki4y2Vi2pL',
#   'name': 'Universally SANAM',
#   'release_date': '2019-08-09',
#   'total_tracks': 5,
#   'url': 'https://open.spotify.com/album/0xPcW40GWPqYki4y2Vi2pL'},
#  {'album_id': '7xV2TzoaVc0ycW7fwBwAml',
#   'name': 'Fine Line',
#   'release_date': '2019-12-13',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/7xV2TzoaVc0ycW7fwBwAml'},
#  {'album_id': '3yVVL2EYLp8g7gT08VvYKy',
#   'name': 'Monster',
#   'release_date': '2020-11-20',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3yVVL2EYLp8g7gT08VvYKy'},
#  {'album_id': '1xWYSg7J7pxTZ113CJVy1P',
#   'name': 'Mad at Disney',
#   'release_date': '2020-07-24',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1xWYSg7J7pxTZ113CJVy1P'},
#  {'album_id': '43dl8hP5uNN9s6YeeJA5fv',
#   'name': 'DÁKITI',
#   'release_date': '2020-10-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/43dl8hP5uNN9s6YeeJA5fv'},
#  {'album_id': '2sBB17RXTamvj7Ncps15AK',
#   'name': 'lovely (with Khalid)',
#   'release_date': '2018-04-19',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2sBB17RXTamvj7Ncps15AK'},
#  {'album_id': '3Ip9JCpT1IF9GvhAxzufTH',
#   'name': 'Tum Mile (Original Motion Picture Soundtrack)',
#   'release_date': '2009-09-08',
#   'total_tracks': 9,
#   'url': 'https://open.spotify.com/album/3Ip9JCpT1IF9GvhAxzufTH'},
#  {'album_id': '4OTAx9un4e6NfoHuVRiOrC',
#   'name': 'Love In The Future (Expanded Edition)',
#   'release_date': '2013-08-30',
#   'total_tracks': 20,
#   'url': 'https://open.spotify.com/album/4OTAx9un4e6NfoHuVRiOrC'},
#  {'album_id': '0ce41LFQaFvOPCMKhs7Npr',
#   'name': 'Yeh Dooriyan',
#   'release_date': '2015-02-03',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/0ce41LFQaFvOPCMKhs7Npr'},
#  {'album_id': '0rA5WWDEVXDEizsgwS2hR4',
#   'name': 'Khatta Meetha',
#   'release_date': '2010-06-21',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/0rA5WWDEVXDEizsgwS2hR4'},
#  {'album_id': '4mFLdK8SkUo3cx8ERLQC92',
#   'name': 'Bachna Ae Haseeno',
#   'release_date': '2008-07-05',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/4mFLdK8SkUo3cx8ERLQC92'},
#  {'album_id': '4nZOPP0atfJbBlkedLYi7t',
#   'name': 'Bajrangi Bhaijaan',
#   'release_date': '2015-07-07',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4nZOPP0atfJbBlkedLYi7t'},
#  {'album_id': '76fVcAIaboYxvTj2xdceIw',
#   'name': 'Haath Toh Laga',
#   'release_date': '2020-10-14',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/76fVcAIaboYxvTj2xdceIw'},
#  {'album_id': '2nCWTEDqE4wUyDPPoSL1p5',
#   'name': 'Level Up',
#   'release_date': '2020-10-26',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2nCWTEDqE4wUyDPPoSL1p5'},
#  {'album_id': '4F87p1aiFwHeU4uu65MaPV',
#   'name': 'Bobby Tarantino II',
#   'release_date': '2018-03-09',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/4F87p1aiFwHeU4uu65MaPV'},
#  {'album_id': '1Czfd5tEby3DbdYNdqzrCa',
#   'name': 'Falling',
#   'release_date': '2018-10-05',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1Czfd5tEby3DbdYNdqzrCa'},
#  {'album_id': '4nZOPP0atfJbBlkedLYi7t',
#   'name': 'Bajrangi Bhaijaan',
#   'release_date': '2015-07-07',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/4nZOPP0atfJbBlkedLYi7t'},
#  {'album_id': '5s5EpS4eQnqCWEJlNWd0Dk',
#   'name': 'Say My Name',
#   'release_date': '2020-09-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5s5EpS4eQnqCWEJlNWd0Dk'},
#  {'album_id': '2rxrGRAq7o65m19MVH2fNN',
#   'name': 'No Losses',
#   'release_date': '2020-07-10',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2rxrGRAq7o65m19MVH2fNN'},
#  {'album_id': '4VUCwdM2v9WfRR8mwZuVq4',
#   'name': 'poems of the past',
#   'release_date': '2020-05-29',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/4VUCwdM2v9WfRR8mwZuVq4'},
#  {'album_id': '2LnYt93b2VqGsZP7jSMIhF',
#   'name': 'Bangers Only, Vol. 1',
#   'release_date': '2020-09-30',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/2LnYt93b2VqGsZP7jSMIhF'},
#  {'album_id': '5ASFrellizlx98SmsItOEm',
#   'name': '',
#   'release_date': '0000',
#   'total_tracks': 6,
#   'url': 'https://open.spotify.com/album/5ASFrellizlx98SmsItOEm'},
#  {'album_id': '06l61IvDCVAeThVR8ajgxj',
#   'name': '',
#   'release_date': '0000',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/06l61IvDCVAeThVR8ajgxj'},
#  {'album_id': '0OK35duHpTPnvqya2d4pnn',
#   'name': 'There for You',
#   'release_date': '2017-05-26',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/0OK35duHpTPnvqya2d4pnn'},
#  {'album_id': '7BISGeB7QwhqRIadxuLHfG',
#   'name': 'Arcade',
#   'release_date': '2019-03-07',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7BISGeB7QwhqRIadxuLHfG'},
#  {'album_id': '2mumCpGmuE9iDeOvMx6XrB',
#   'name': 'The Papercut Chronicles II',
#   'release_date': '2011-11-11',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/2mumCpGmuE9iDeOvMx6XrB'},
#  {'album_id': '1Xi5uKogVQQe4ftctMc8YI',
#   'name': 'Shinzo wo Sasageyo! (TV Size)',
#   'release_date': '2017-04-02',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/1Xi5uKogVQQe4ftctMc8YI'},
#  {'album_id': '3KDuNEtT7I41hNbzMUakyq',
#   'name': 'Good Life (with G-Eazy & Kehlani)',
#   'release_date': '2017-03-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3KDuNEtT7I41hNbzMUakyq'},
#  {'album_id': '5FXIqS1XqbpfOKNoi5VUwS',
#   'name': 'See You Again (feat. Charlie Puth)',
#   'release_date': '2015',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/5FXIqS1XqbpfOKNoi5VUwS'},
#  {'album_id': '5NeG7Rk7ZUGVgvIRxPOmJ3',
#   'name': 'Troubadour (Champion Edition - Asian Version)',
#   'release_date': '2009',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/5NeG7Rk7ZUGVgvIRxPOmJ3'},
#  {'album_id': '2qIbHfs93z6eDwGoAdCkXA',
#   'name': '8 Letters',
#   'release_date': '2018-08-31',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/2qIbHfs93z6eDwGoAdCkXA'},
#  {'album_id': '6YMSXPIHkA2jPIlFHuejXW',
#   'name': 'All My Demons Greeting Me As A Friend (Deluxe)',
#   'release_date': '2016-03-11',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/6YMSXPIHkA2jPIlFHuejXW'},
#  {'album_id': '00wSTrFxoSzA7eeS1UxHgd',
#   'name': 'Sin Miedo (del Amor y Otros Demonios) ∞',
#   'release_date': '2020-12-04',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/00wSTrFxoSzA7eeS1UxHgd'},
#  {'album_id': '6cunQQ7YZisYOoiFu2ywIq',
#   'name': 'Up All Night',
#   'release_date': '2012-05-25',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/6cunQQ7YZisYOoiFu2ywIq'},
#  {'album_id': '66FPnVL9G4CMKy3wvaGTcr',
#   'name': 'drivers license',
#   'release_date': '2021-01-08',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/66FPnVL9G4CMKy3wvaGTcr'},
#  {'album_id': '6FgtuX3PtiB5civjHYhc52',
#   'name': 'Safe Haven',
#   'release_date': '2017-05-05',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/6FgtuX3PtiB5civjHYhc52'},
#  {'album_id': '14lSyFVCuhvEoW7ogOIzD0',
#   'name': 'glisten',
#   'release_date': '2018-05-04',
#   'total_tracks': 4,
#   'url': 'https://open.spotify.com/album/14lSyFVCuhvEoW7ogOIzD0'},
#  {'album_id': '3cfAM8b8KqJRoIzt3zLKqw',
#   'name': 'A Head Full of Dreams',
#   'release_date': '2015-12-04',
#   'total_tracks': 11,
#   'url': 'https://open.spotify.com/album/3cfAM8b8KqJRoIzt3zLKqw'},
#  {'album_id': '4g1ZRSobMefqF6nelkgibi',
#   'name': "Hollywood's Bleeding",
#   'release_date': '2019-09-06',
#   'total_tracks': 17,
#   'url': 'https://open.spotify.com/album/4g1ZRSobMefqF6nelkgibi'},
#  {'album_id': '3T4tUhGYeRNVUGevb0wThu',
#   'name': '÷ (Deluxe)',
#   'release_date': '2017-03-03',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#  {'album_id': '6lheAtw3IcJvflIhLbykih',
#   'name': 'CKay The First',
#   'release_date': '2019-08-30',
#   'total_tracks': 8,
#   'url': 'https://open.spotify.com/album/6lheAtw3IcJvflIhLbykih'},
#  {'album_id': '2DKSZvMj7Da6rzNVPMgREj',
#   'name': 'Raataan Lambiyan (From "Shershaah")',
#   'release_date': '2021-07-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2DKSZvMj7Da6rzNVPMgREj'},
#  {'album_id': '0boA7GUGSxOMWwdnnTR0yI',
#   'name': 'Into Your Arms (feat. Ava Max)',
#   'release_date': '2018-06-08',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/0boA7GUGSxOMWwdnnTR0yI'},
#  {'album_id': '4QLAtpLNUsHEYrcHXmMIZZ',
#   'name': 'STAY (with Justin Bieber)',
#   'release_date': '2021-07-09',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/4QLAtpLNUsHEYrcHXmMIZZ'}]

# %%
data['items'][0]
# Out:
# {'added_at': '2019-06-16T02:55:39Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/316qtia7vgfths2tkig4q727ywd4'},
#   'href': 'https://api.spotify.com/v1/users/316qtia7vgfths2tkig4q727ywd4',
#   'id': '316qtia7vgfths2tkig4q727ywd4',
#   'type': 'user',
#   'uri': 'spotify:user:316qtia7vgfths2tkig4q727ywd4'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['KR'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['KR'],
#    'type': 'album',
#    'album_type': 'single',
#    'href': 'https://api.spotify.com/v1/albums/21dd5QyItuoqvPkViQXlKf',
#    'id': '21dd5QyItuoqvPkViQXlKf',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d8315d631ef620fbbff03d5b',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d8315d631ef620fbbff03d5b',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851d8315d631ef620fbbff03d5b',
#      'width': 64}],
#    'name': 'You Need To Calm Down',
#    'release_date': '2019-06-14',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:21dd5QyItuoqvPkViQXlKf',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#      'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#      'id': '06HL4z0CvFAxyc27GXpf02',
#      'name': 'Taylor Swift',
#      'type': 'artist',
#      'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/21dd5QyItuoqvPkViQXlKf'},
#    'total_tracks': 1},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#     'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#     'id': '06HL4z0CvFAxyc27GXpf02',
#     'name': 'Taylor Swift',
#     'type': 'artist',
#     'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#   'disc_number': 1,
#   'track_number': 1,
#   'duration_ms': 171386,
#   'external_ids': {'isrc': 'USUG11901470'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/29fRTIKsJhLUJoldM89GZS'},
#   'href': 'https://api.spotify.com/v1/tracks/29fRTIKsJhLUJoldM89GZS',
#   'id': '29fRTIKsJhLUJoldM89GZS',
#   'name': 'You Need To Calm Down',
#   'popularity': 18,
#   'uri': 'spotify:track:29fRTIKsJhLUJoldM89GZS',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '06HL4z0CvFAxyc27GXpf02',
#   'artist_name': 'Taylor Swift',
#   'external_url': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02'},
#  {'artist_id': '7n2wHs1TKAczGzO7Dd2rGr',
#   'artist_name': 'Shawn Mendes',
#   'external_url': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr'},
#  {'artist_id': '4nDoRrQiYLoBzwC5BhVJzF',
#   'artist_name': 'Camila Cabello',
#   'external_url': 'https://api.spotify.com/v1/artists/4nDoRrQiYLoBzwC5BhVJzF'},
#  {'artist_id': '6jJ0s89eD6GaHleKKya26X',
#   'artist_name': 'Katy Perry',
#   'external_url': 'https://api.spotify.com/v1/artists/6jJ0s89eD6GaHleKKya26X'},
#  {'artist_id': '7n2wHs1TKAczGzO7Dd2rGr',
#   'artist_name': 'Shawn Mendes',
#   'external_url': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr'},
#  {'artist_id': '1psakk7GVUl85AnTEvwtk2',
#   'artist_name': 'DHARIA',
#   'external_url': 'https://api.spotify.com/v1/artists/1psakk7GVUl85AnTEvwtk2'},
#  {'artist_id': '0LyfQWJT6nXafLPZqxe9Of',
#   'artist_name': '',
#   'external_url': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of'},
#  {'artist_id': '69GGBxA162lTqCwzJG5jLp',
#   'artist_name': 'The Chainsmokers',
#   'external_url': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp'},
#  {'artist_id': '76yeOnINtQSXyoEHbkYmtY',
#   'artist_name': 'Drew Love',
#   'external_url': 'https://api.spotify.com/v1/artists/76yeOnINtQSXyoEHbkYmtY'},
#  {'artist_id': '1xLhhhPXc6NUNxUXDG5Psb',
#   'artist_name': 'Ruhde',
#   'external_url': 'https://api.spotify.com/v1/artists/1xLhhhPXc6NUNxUXDG5Psb'},
#  {'artist_id': '53XhwfbYqKCa1cC15pYq2q',
#   'artist_name': 'Imagine Dragons',
#   'external_url': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q'},
#  {'artist_id': '0gadJ2b9A4SKsB1RFkBb66',
#   'artist_name': 'Passenger',
#   'external_url': 'https://api.spotify.com/v1/artists/0gadJ2b9A4SKsB1RFkBb66'},
#  {'artist_id': '7HBai5xymOxIWoMWvWshe1',
#   'artist_name': 'Teriyaki Boyz',
#   'external_url': 'https://api.spotify.com/v1/artists/7HBai5xymOxIWoMWvWshe1'},
#  {'artist_id': '2EWIKpC6npt0GTe1Cq1KDm',
#   'artist_name': 'Yoshiki',
#   'external_url': 'https://api.spotify.com/v1/artists/2EWIKpC6npt0GTe1Cq1KDm'},
#  {'artist_id': '0ZXSQd2JNOfwJcLNbX0jpN',
#   'artist_name': 'HYDE',
#   'external_url': 'https://api.spotify.com/v1/artists/0ZXSQd2JNOfwJcLNbX0jpN'},
#  {'artist_id': '3B9O5mYYw89fFXkwKh7jCS',
#   'artist_name': 'TK from Ling tosite sigure',
#   'external_url': 'https://api.spotify.com/v1/artists/3B9O5mYYw89fFXkwKh7jCS'},
#  {'artist_id': '5y2Xq6xcjJb2jVM54GHK3t',
#   'artist_name': 'John Legend',
#   'external_url': 'https://api.spotify.com/v1/artists/5y2Xq6xcjJb2jVM54GHK3t'},
#  {'artist_id': '53XhwfbYqKCa1cC15pYq2q',
#   'artist_name': 'Imagine Dragons',
#   'external_url': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q'},
#  {'artist_id': '4f7KfxeHq9BiylGmyXepGt',
#   'artist_name': 'Tanishk Bagchi',
#   'external_url': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt'},
#  {'artist_id': '7C5xVXoqim1TICnCMZ9A6P',
#   'artist_name': 'Zahrah S Khan',
#   'external_url': 'https://api.spotify.com/v1/artists/7C5xVXoqim1TICnCMZ9A6P'},
#  {'artist_id': '7gXb99Sf9nNmpNYeAgIQFG',
#   'artist_name': 'Sub Urban',
#   'external_url': 'https://api.spotify.com/v1/artists/7gXb99Sf9nNmpNYeAgIQFG'},
#  {'artist_id': '04gDigrS5kc9YWfZHwBETP',
#   'artist_name': 'Maroon 5',
#   'external_url': 'https://api.spotify.com/v1/artists/04gDigrS5kc9YWfZHwBETP'},
#  {'artist_id': '3Nrfpe0tUJi4K4DXYWgMUX',
#   'artist_name': 'BTS',
#   'external_url': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX'},
#  {'artist_id': '26VFTg2z8YR0cCuwLzESi2',
#   'artist_name': 'Halsey',
#   'external_url': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '1zNqQNIdeOUZHb8zbZRFMX',
#   'artist_name': 'Swae Lee',
#   'external_url': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX'},
#  {'artist_id': '6BrvowZBreEkXzJQMpL174',
#   'artist_name': 'Hardwell',
#   'external_url': 'https://api.spotify.com/v1/artists/6BrvowZBreEkXzJQMpL174'},
#  {'artist_id': '0RMeG9M8QFzss9bAbq99KA',
#   'artist_name': 'Maddix',
#   'external_url': 'https://api.spotify.com/v1/artists/0RMeG9M8QFzss9bAbq99KA'},
#  {'artist_id': '53XhwfbYqKCa1cC15pYq2q',
#   'artist_name': 'Imagine Dragons',
#   'external_url': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q'},
#  {'artist_id': '69GGBxA162lTqCwzJG5jLp',
#   'artist_name': 'The Chainsmokers',
#   'external_url': 'https://api.spotify.com/v1/artists/69GGBxA162lTqCwzJG5jLp'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'external_url': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU'},
#  {'artist_id': '7vk5e3vY1uw9plTHJAMwjN',
#   'artist_name': 'Alan Walker',
#   'external_url': 'https://api.spotify.com/v1/artists/7vk5e3vY1uw9plTHJAMwjN'},
#  {'artist_id': '4npEfmQ6YuiwW1GpUmaq3F',
#   'artist_name': 'Ava Max',
#   'external_url': 'https://api.spotify.com/v1/artists/4npEfmQ6YuiwW1GpUmaq3F'},
#  {'artist_id': '5gVozagAcRKYCeAVnlC3Nk',
#   'artist_name': 'Vilen',
#   'external_url': 'https://api.spotify.com/v1/artists/5gVozagAcRKYCeAVnlC3Nk'},
#  {'artist_id': '1mYsTxnqsietFxj1OgoGbG',
#   'artist_name': 'A.R. Rahman',
#   'external_url': 'https://api.spotify.com/v1/artists/1mYsTxnqsietFxj1OgoGbG'},
#  {'artist_id': '00sCATpEvwH48ays7PlQFU',
#   'artist_name': 'Jonita Gandhi',
#   'external_url': 'https://api.spotify.com/v1/artists/00sCATpEvwH48ays7PlQFU'},
#  {'artist_id': '0xWGBvlwCBHAgXyR7TmPwp',
#   'artist_name': 'Hriday Gattani',
#   'external_url': 'https://api.spotify.com/v1/artists/0xWGBvlwCBHAgXyR7TmPwp'},
#  {'artist_id': '49YbNTLaaAbZHLtDI2aPGL',
#   'artist_name': 'Tesher',
#   'external_url': 'https://api.spotify.com/v1/artists/49YbNTLaaAbZHLtDI2aPGL'},
#  {'artist_id': '72beYOeW2sb2yfcS4JsRvb',
#   'artist_name': 'Ritviz',
#   'external_url': 'https://api.spotify.com/v1/artists/72beYOeW2sb2yfcS4JsRvb'},
#  {'artist_id': '008PpLcKUtVXle6JSwkq3I',
#   'artist_name': 'Emiway Bantai',
#   'external_url': 'https://api.spotify.com/v1/artists/008PpLcKUtVXle6JSwkq3I'},
#  {'artist_id': '3JhNCzhSMTxs9WLGJJxWOY',
#   'artist_name': 'Macklemore',
#   'external_url': 'https://api.spotify.com/v1/artists/3JhNCzhSMTxs9WLGJJxWOY'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '1lmU3giNF3CSbkVSQmLpHQ',
#   'artist_name': 'Surf Mesa',
#   'external_url': 'https://api.spotify.com/v1/artists/1lmU3giNF3CSbkVSQmLpHQ'},
#  {'artist_id': '4ArPQ1Opcksbbf3CPwEjWE',
#   'artist_name': 'Emilee',
#   'external_url': 'https://api.spotify.com/v1/artists/4ArPQ1Opcksbbf3CPwEjWE'},
#  {'artist_id': '6bmlMHgSheBauioMgKv2tn',
#   'artist_name': 'Powfu',
#   'external_url': 'https://api.spotify.com/v1/artists/6bmlMHgSheBauioMgKv2tn'},
#  {'artist_id': '35l9BRT7MXmM8bv2WDQiyB',
#   'artist_name': 'beabadoobee',
#   'external_url': 'https://api.spotify.com/v1/artists/35l9BRT7MXmM8bv2WDQiyB'},
#  {'artist_id': '2NjfBq1NflQcKSeiDooVjY',
#   'artist_name': 'Tones And I',
#   'external_url': 'https://api.spotify.com/v1/artists/2NjfBq1NflQcKSeiDooVjY'},
#  {'artist_id': '0LyfQWJT6nXafLPZqxe9Of',
#   'artist_name': '',
#   'external_url': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of'},
#  {'artist_id': '56mfhUDKa1vec6rSLZV5Eg',
#   'artist_name': 'Jawsh 685',
#   'external_url': 'https://api.spotify.com/v1/artists/56mfhUDKa1vec6rSLZV5Eg'},
#  {'artist_id': '07YZf4WDAMNwqr4jfgOZ8y',
#   'artist_name': 'Jason Derulo',
#   'external_url': 'https://api.spotify.com/v1/artists/07YZf4WDAMNwqr4jfgOZ8y'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '3Nrfpe0tUJi4K4DXYWgMUX',
#   'artist_name': 'BTS',
#   'external_url': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX'},
#  {'artist_id': '56mfhUDKa1vec6rSLZV5Eg',
#   'artist_name': 'Jawsh 685',
#   'external_url': 'https://api.spotify.com/v1/artists/56mfhUDKa1vec6rSLZV5Eg'},
#  {'artist_id': '07YZf4WDAMNwqr4jfgOZ8y',
#   'artist_name': 'Jason Derulo',
#   'external_url': 'https://api.spotify.com/v1/artists/07YZf4WDAMNwqr4jfgOZ8y'},
#  {'artist_id': '3Nrfpe0tUJi4K4DXYWgMUX',
#   'artist_name': 'BTS',
#   'external_url': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '63yrD80RY3RNEM2YDpUpO8',
#   'artist_name': 'Melanie Martinez',
#   'external_url': 'https://api.spotify.com/v1/artists/63yrD80RY3RNEM2YDpUpO8'},
#  {'artist_id': '523y9KSneKh6APd1hKxLuF',
#   'artist_name': 'Master KG',
#   'external_url': 'https://api.spotify.com/v1/artists/523y9KSneKh6APd1hKxLuF'},
#  {'artist_id': '4cfKtwkefMW3aiXtxfw8w6',
#   'artist_name': 'Nomcebo Zikode',
#   'external_url': 'https://api.spotify.com/v1/artists/4cfKtwkefMW3aiXtxfw8w6'},
#  {'artist_id': '0LyfQWJT6nXafLPZqxe9Of',
#   'artist_name': '',
#   'external_url': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of'},
#  {'artist_id': '2GoeZ0qOTt6kjsWW4eA6LS',
#   'artist_name': 'Darshan Raval',
#   'external_url': 'https://api.spotify.com/v1/artists/2GoeZ0qOTt6kjsWW4eA6LS'},
#  {'artist_id': '5f4QpKfy7ptCHwTqspnSJI',
#   'artist_name': 'Neha Kakkar',
#   'external_url': 'https://api.spotify.com/v1/artists/5f4QpKfy7ptCHwTqspnSJI'},
#  {'artist_id': '3pQ4aA7dkolyjUAMrVScgh',
#   'artist_name': 'Manan Bhardwaj',
#   'external_url': 'https://api.spotify.com/v1/artists/3pQ4aA7dkolyjUAMrVScgh'},
#  {'artist_id': '4dyndZiWds3qEwmDsMYbDL',
#   'artist_name': 'Vibe2Vibe',
#   'external_url': 'https://api.spotify.com/v1/artists/4dyndZiWds3qEwmDsMYbDL'},
#  {'artist_id': '0P8lyTR2bRQd31s7etCmDu',
#   'artist_name': 'Alex Benjamin',
#   'external_url': 'https://api.spotify.com/v1/artists/0P8lyTR2bRQd31s7etCmDu'},
#  {'artist_id': '4cqiR83xdaQFZqqUiAjp4I',
#   'artist_name': 'Ibara',
#   'external_url': 'https://api.spotify.com/v1/artists/4cqiR83xdaQFZqqUiAjp4I'},
#  {'artist_id': '7vk5e3vY1uw9plTHJAMwjN',
#   'artist_name': 'Alan Walker',
#   'external_url': 'https://api.spotify.com/v1/artists/7vk5e3vY1uw9plTHJAMwjN'},
#  {'artist_id': '6pWcSL9wSJZQ9ne0TnhdWr',
#   'artist_name': 'K-391',
#   'external_url': 'https://api.spotify.com/v1/artists/6pWcSL9wSJZQ9ne0TnhdWr'},
#  {'artist_id': '61pvU6ZLOF3bl0IOtbmME7',
#   'artist_name': 'Emelie Hollow',
#   'external_url': 'https://api.spotify.com/v1/artists/61pvU6ZLOF3bl0IOtbmME7'},
#  {'artist_id': '1r4hJ1h58CWwUQe3MxPuau',
#   'artist_name': 'Maluma',
#   'external_url': 'https://api.spotify.com/v1/artists/1r4hJ1h58CWwUQe3MxPuau'},
#  {'artist_id': '1Xyo4u8uXC1ZmMpatF05PJ',
#   'artist_name': 'The Weeknd',
#   'external_url': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ'},
#  {'artist_id': '3Nrfpe0tUJi4K4DXYWgMUX',
#   'artist_name': 'BTS',
#   'external_url': 'https://api.spotify.com/v1/artists/3Nrfpe0tUJi4K4DXYWgMUX'},
#  {'artist_id': '4Ai0pGz6GhQavjzaRhPTvz',
#   'artist_name': 'DIVINE',
#   'external_url': 'https://api.spotify.com/v1/artists/4Ai0pGz6GhQavjzaRhPTvz'},
#  {'artist_id': '1oMKeiHXRkg7tNqwhaS3fu',
#   'artist_name': 'MC Altaf',
#   'external_url': 'https://api.spotify.com/v1/artists/1oMKeiHXRkg7tNqwhaS3fu'},
#  {'artist_id': '7qPISKHhhKDLZTmYcX7bWd',
#   'artist_name': 'Stylo G',
#   'external_url': 'https://api.spotify.com/v1/artists/7qPISKHhhKDLZTmYcX7bWd'},
#  {'artist_id': '3vQ75vDDu0nhfHuEW3n17Z',
#   'artist_name': 'Phenom',
#   'external_url': 'https://api.spotify.com/v1/artists/3vQ75vDDu0nhfHuEW3n17Z'},
#  {'artist_id': '5f4QpKfy7ptCHwTqspnSJI',
#   'artist_name': 'Neha Kakkar',
#   'external_url': 'https://api.spotify.com/v1/artists/5f4QpKfy7ptCHwTqspnSJI'},
#  {'artist_id': '1tqysapcCh1lWEAc9dIFpa',
#   'artist_name': 'Jubin Nautiyal',
#   'external_url': 'https://api.spotify.com/v1/artists/1tqysapcCh1lWEAc9dIFpa'},
#  {'artist_id': '5gZhfbckaWo89OzDSk3gdT',
#   'artist_name': 'Jaani',
#   'external_url': 'https://api.spotify.com/v1/artists/5gZhfbckaWo89OzDSk3gdT'},
#  {'artist_id': '72beYOeW2sb2yfcS4JsRvb',
#   'artist_name': 'Ritviz',
#   'external_url': 'https://api.spotify.com/v1/artists/72beYOeW2sb2yfcS4JsRvb'},
#  {'artist_id': '72beYOeW2sb2yfcS4JsRvb',
#   'artist_name': 'Ritviz',
#   'external_url': 'https://api.spotify.com/v1/artists/72beYOeW2sb2yfcS4JsRvb'},
#  {'artist_id': '2oBG74gAocPMFv6Ij9ykdo',
#   'artist_name': 'Seedhe Maut',
#   'external_url': 'https://api.spotify.com/v1/artists/2oBG74gAocPMFv6Ij9ykdo'},
#  {'artist_id': '72beYOeW2sb2yfcS4JsRvb',
#   'artist_name': 'Ritviz',
#   'external_url': 'https://api.spotify.com/v1/artists/72beYOeW2sb2yfcS4JsRvb'},
#  {'artist_id': '3gBKY0y3dFFVRqicLnVZYz',
#   'artist_name': 'Alka Yagnik',
#   'external_url': 'https://api.spotify.com/v1/artists/3gBKY0y3dFFVRqicLnVZYz'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'external_url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '45PG2L6Fh2XvYL4ONzpdoW',
#   'artist_name': 'Dino James',
#   'external_url': 'https://api.spotify.com/v1/artists/45PG2L6Fh2XvYL4ONzpdoW'},
#  {'artist_id': '0EQ7TTs23yrdYKA2S588kt',
#   'artist_name': 'Kaprila',
#   'external_url': 'https://api.spotify.com/v1/artists/0EQ7TTs23yrdYKA2S588kt'},
#  {'artist_id': '45PG2L6Fh2XvYL4ONzpdoW',
#   'artist_name': 'Dino James',
#   'external_url': 'https://api.spotify.com/v1/artists/45PG2L6Fh2XvYL4ONzpdoW'},
#  {'artist_id': '0EQ7TTs23yrdYKA2S588kt',
#   'artist_name': 'Kaprila',
#   'external_url': 'https://api.spotify.com/v1/artists/0EQ7TTs23yrdYKA2S588kt'},
#  {'artist_id': '56SjZARoEvag3RoKWIb16j',
#   'artist_name': 'B Praak',
#   'external_url': 'https://api.spotify.com/v1/artists/56SjZARoEvag3RoKWIb16j'},
#  {'artist_id': '0w0mlcvl7QH28Cs28O6waY',
#   'artist_name': 'Akshay Kumar',
#   'external_url': 'https://api.spotify.com/v1/artists/0w0mlcvl7QH28Cs28O6waY'},
#  {'artist_id': '2vCsnF6h4c2b1csudqJiV5',
#   'artist_name': 'Nupur Sanon',
#   'external_url': 'https://api.spotify.com/v1/artists/2vCsnF6h4c2b1csudqJiV5'},
#  {'artist_id': '7o7doCwqft91WC690aglWC',
#   'artist_name': 'Sanam',
#   'external_url': 'https://api.spotify.com/v1/artists/7o7doCwqft91WC690aglWC'},
#  {'artist_id': '6KImCVD70vtIoJWnq6nGn3',
#   'artist_name': 'Harry Styles',
#   'external_url': 'https://api.spotify.com/v1/artists/6KImCVD70vtIoJWnq6nGn3'},
#  {'artist_id': '7n2wHs1TKAczGzO7Dd2rGr',
#   'artist_name': 'Shawn Mendes',
#   'external_url': 'https://api.spotify.com/v1/artists/7n2wHs1TKAczGzO7Dd2rGr'},
#  {'artist_id': '1uNFoZAHBGtllmzznpCI3s',
#   'artist_name': 'Justin Bieber',
#   'external_url': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s'},
#  {'artist_id': '3QJUFtGBGL05vo0kCJZsmT',
#   'artist_name': 'salem ilese',
#   'external_url': 'https://api.spotify.com/v1/artists/3QJUFtGBGL05vo0kCJZsmT'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '6nVcHLIgY5pE2YCl8ubca1',
#   'artist_name': 'JHAYCO',
#   'external_url': 'https://api.spotify.com/v1/artists/6nVcHLIgY5pE2YCl8ubca1'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '6LuN9FCkKOj5PcnpouEgny',
#   'artist_name': 'Khalid',
#   'external_url': 'https://api.spotify.com/v1/artists/6LuN9FCkKOj5PcnpouEgny'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '3tHD07u1ON4uHxmnT9rwqZ',
#   'artist_name': 'Neeraj Shridhar',
#   'external_url': 'https://api.spotify.com/v1/artists/3tHD07u1ON4uHxmnT9rwqZ'},
#  {'artist_id': '5y2Xq6xcjJb2jVM54GHK3t',
#   'artist_name': 'John Legend',
#   'external_url': 'https://api.spotify.com/v1/artists/5y2Xq6xcjJb2jVM54GHK3t'},
#  {'artist_id': '5GnnSrwNCGyfAU4zuIytiS',
#   'artist_name': 'Mohit Chauhan',
#   'external_url': 'https://api.spotify.com/v1/artists/5GnnSrwNCGyfAU4zuIytiS'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4fEkbug6kZzzJ8eYX6Kbbp',
#   'artist_name': 'KK',
#   'external_url': 'https://api.spotify.com/v1/artists/4fEkbug6kZzzJ8eYX6Kbbp'},
#  {'artist_id': '3eDT9fwXKuHWFvgZaaYC5v',
#   'artist_name': 'Sunidhi Chauhan',
#   'external_url': 'https://api.spotify.com/v1/artists/3eDT9fwXKuHWFvgZaaYC5v'},
#  {'artist_id': '6Mv8GjQa7LKUGCAqa9qqdb',
#   'artist_name': 'Vishal-Shekhar',
#   'external_url': 'https://api.spotify.com/v1/artists/6Mv8GjQa7LKUGCAqa9qqdb'},
#  {'artist_id': '4fEkbug6kZzzJ8eYX6Kbbp',
#   'artist_name': 'KK',
#   'external_url': 'https://api.spotify.com/v1/artists/4fEkbug6kZzzJ8eYX6Kbbp'},
#  {'artist_id': '19LIHDDSHBD5NyYHI3gpzB',
#   'artist_name': 'Shilpa Rao',
#   'external_url': 'https://api.spotify.com/v1/artists/19LIHDDSHBD5NyYHI3gpzB'},
#  {'artist_id': '4GEyPR3J4DYvuTRuPJQ0CW',
#   'artist_name': 'Anvita Dutt Guptan',
#   'external_url': 'https://api.spotify.com/v1/artists/4GEyPR3J4DYvuTRuPJQ0CW'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4fEkbug6kZzzJ8eYX6Kbbp',
#   'artist_name': 'KK',
#   'external_url': 'https://api.spotify.com/v1/artists/4fEkbug6kZzzJ8eYX6Kbbp'},
#  {'artist_id': '3GBSge8pq7mpezUQl0GAOA',
#   'artist_name': 'Kausar Munir',
#   'external_url': 'https://api.spotify.com/v1/artists/3GBSge8pq7mpezUQl0GAOA'},
#  {'artist_id': '7n5rLZ6NonT1BXW1fQmbuA',
#   'artist_name': 'Fotty Seven',
#   'external_url': 'https://api.spotify.com/v1/artists/7n5rLZ6NonT1BXW1fQmbuA'},
#  {'artist_id': '1yCVvGnMTuLeNzbXtgAytL',
#   'artist_name': 'Rebel 7',
#   'external_url': 'https://api.spotify.com/v1/artists/1yCVvGnMTuLeNzbXtgAytL'},
#  {'artist_id': '07iEy1AecUPVzfC2J2gCHR',
#   'artist_name': 'Ikka',
#   'external_url': 'https://api.spotify.com/v1/artists/07iEy1AecUPVzfC2J2gCHR'},
#  {'artist_id': '4Ai0pGz6GhQavjzaRhPTvz',
#   'artist_name': 'DIVINE',
#   'external_url': 'https://api.spotify.com/v1/artists/4Ai0pGz6GhQavjzaRhPTvz'},
#  {'artist_id': '12bMjwsp9WCkVM3kscRAUE',
#   'artist_name': 'Kaater',
#   'external_url': 'https://api.spotify.com/v1/artists/12bMjwsp9WCkVM3kscRAUE'},
#  {'artist_id': '4xRYI6VqpkE3UwrDrAZL8L',
#   'artist_name': 'Logic',
#   'external_url': 'https://api.spotify.com/v1/artists/4xRYI6VqpkE3UwrDrAZL8L'},
#  {'artist_id': '64KEffDW9EtZ1y2vBYgq8T',
#   'artist_name': 'Marshmello',
#   'external_url': 'https://api.spotify.com/v1/artists/64KEffDW9EtZ1y2vBYgq8T'},
#  {'artist_id': '7uaIm6Pw7xplS8Dy06V6pT',
#   'artist_name': 'Trevor Daniel',
#   'external_url': 'https://api.spotify.com/v1/artists/7uaIm6Pw7xplS8Dy06V6pT'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'external_url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '1tqysapcCh1lWEAc9dIFpa',
#   'artist_name': 'Jubin Nautiyal',
#   'external_url': 'https://api.spotify.com/v1/artists/1tqysapcCh1lWEAc9dIFpa'},
#  {'artist_id': '72APa8QPdPUhGzNMciz1wI',
#   'artist_name': 'Neelesh Misra',
#   'external_url': 'https://api.spotify.com/v1/artists/72APa8QPdPUhGzNMciz1wI'},
#  {'artist_id': '5C1S9XwxMuuCciutwMhp5t',
#   'artist_name': 'KR$NA',
#   'external_url': 'https://api.spotify.com/v1/artists/5C1S9XwxMuuCciutwMhp5t'},
#  {'artist_id': '5C1S9XwxMuuCciutwMhp5t',
#   'artist_name': 'KR$NA',
#   'external_url': 'https://api.spotify.com/v1/artists/5C1S9XwxMuuCciutwMhp5t'},
#  {'artist_id': '6bmlMHgSheBauioMgKv2tn',
#   'artist_name': 'Powfu',
#   'external_url': 'https://api.spotify.com/v1/artists/6bmlMHgSheBauioMgKv2tn'},
#  {'artist_id': '1bq8rqNnfrojn0OSAfeNXJ',
#   'artist_name': 'Sarcastic Sounds',
#   'external_url': 'https://api.spotify.com/v1/artists/1bq8rqNnfrojn0OSAfeNXJ'},
#  {'artist_id': '1ScHz7wPPxVTEKsc9g3Z0c',
#   'artist_name': 'Rxseboy',
#   'external_url': 'https://api.spotify.com/v1/artists/1ScHz7wPPxVTEKsc9g3Z0c'},
#  {'artist_id': '6aWaRINbCAt1TPJYJuDvtA',
#   'artist_name': 'Bangers Only',
#   'external_url': 'https://api.spotify.com/v1/artists/6aWaRINbCAt1TPJYJuDvtA'},
#  {'artist_id': '1u5hEHvd4fpHDUye3r9lAm',
#   'artist_name': 'fawlin',
#   'external_url': 'https://api.spotify.com/v1/artists/1u5hEHvd4fpHDUye3r9lAm'},
#  {'artist_id': '5TvdGhdmRObqOkU6eGfXb5',
#   'artist_name': 'Preston Pablo',
#   'external_url': 'https://api.spotify.com/v1/artists/5TvdGhdmRObqOkU6eGfXb5'},
#  {'artist_id': '0j1SEv3uBn3CBFglK3cj3A',
#   'artist_name': 'Chill Only',
#   'external_url': 'https://api.spotify.com/v1/artists/0j1SEv3uBn3CBFglK3cj3A'},
#  {'artist_id': '0LyfQWJT6nXafLPZqxe9Of',
#   'artist_name': '',
#   'external_url': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of'},
#  {'artist_id': '0LyfQWJT6nXafLPZqxe9Of',
#   'artist_name': '',
#   'external_url': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of'},
#  {'artist_id': '60d24wfXkVzDSfLS6hyCjZ',
#   'artist_name': 'Martin Garrix',
#   'external_url': 'https://api.spotify.com/v1/artists/60d24wfXkVzDSfLS6hyCjZ'},
#  {'artist_id': '3WGpXCj9YhhfX11TToZcXP',
#   'artist_name': 'Troye Sivan',
#   'external_url': 'https://api.spotify.com/v1/artists/3WGpXCj9YhhfX11TToZcXP'},
#  {'artist_id': '3klZnJvYGIbWritVwQD434',
#   'artist_name': 'Duncan Laurence',
#   'external_url': 'https://api.spotify.com/v1/artists/3klZnJvYGIbWritVwQD434'},
#  {'artist_id': '4IJczjB0fJ04gs4uvP0Fli',
#   'artist_name': 'Gym Class Heroes',
#   'external_url': 'https://api.spotify.com/v1/artists/4IJczjB0fJ04gs4uvP0Fli'},
#  {'artist_id': '4bYPcJP5jwMhSivRcqie2n',
#   'artist_name': 'Adam Levine',
#   'external_url': 'https://api.spotify.com/v1/artists/4bYPcJP5jwMhSivRcqie2n'},
#  {'artist_id': '3eNYrVLcWfjJ9JdH9kiPJO',
#   'artist_name': 'Linked Horizon',
#   'external_url': 'https://api.spotify.com/v1/artists/3eNYrVLcWfjJ9JdH9kiPJO'},
#  {'artist_id': '02kJSzxNuaWGqwubyUba0Z',
#   'artist_name': 'G-Eazy',
#   'external_url': 'https://api.spotify.com/v1/artists/02kJSzxNuaWGqwubyUba0Z'},
#  {'artist_id': '0cGUm45nv7Z6M6qdXYQGTX',
#   'artist_name': 'Kehlani',
#   'external_url': 'https://api.spotify.com/v1/artists/0cGUm45nv7Z6M6qdXYQGTX'},
#  {'artist_id': '137W8MRPWKqSmrBGDBFSop',
#   'artist_name': 'Wiz Khalifa',
#   'external_url': 'https://api.spotify.com/v1/artists/137W8MRPWKqSmrBGDBFSop'},
#  {'artist_id': '6VuMaDnrHyPL1p4EHjYLi7',
#   'artist_name': 'Charlie Puth',
#   'external_url': 'https://api.spotify.com/v1/artists/6VuMaDnrHyPL1p4EHjYLi7'},
#  {'artist_id': '7pGyQZx9thVa8GxMBeXscB',
#   'artist_name': "K'NAAN",
#   'external_url': 'https://api.spotify.com/v1/artists/7pGyQZx9thVa8GxMBeXscB'},
#  {'artist_id': '2jnIB6XdLvnJUeNTy5A0J2',
#   'artist_name': "Why Don't We",
#   'external_url': 'https://api.spotify.com/v1/artists/2jnIB6XdLvnJUeNTy5A0J2'},
#  {'artist_id': '1WgXqy2Dd70QQOU7Ay074N',
#   'artist_name': 'AURORA',
#   'external_url': 'https://api.spotify.com/v1/artists/1WgXqy2Dd70QQOU7Ay074N'},
#  {'artist_id': '1U1el3k54VvEUzo3ybLPlM',
#   'artist_name': 'Kali Uchis',
#   'external_url': 'https://api.spotify.com/v1/artists/1U1el3k54VvEUzo3ybLPlM'},
#  {'artist_id': '4AK6F7OLvEQ5QYCBNiQWHq',
#   'artist_name': 'One Direction',
#   'external_url': 'https://api.spotify.com/v1/artists/4AK6F7OLvEQ5QYCBNiQWHq'},
#  {'artist_id': '1McMsnEElThX1knmY4oliG',
#   'artist_name': 'Olivia Rodrigo',
#   'external_url': 'https://api.spotify.com/v1/artists/1McMsnEElThX1knmY4oliG'},
#  {'artist_id': '2WzaAvm2bBCf4pEhyuDgCY',
#   'artist_name': 'Ruth B.',
#   'external_url': 'https://api.spotify.com/v1/artists/2WzaAvm2bBCf4pEhyuDgCY'},
#  {'artist_id': '3gIRvgZssIb9aiirIg0nI3',
#   'artist_name': 'Jeremy Zucker',
#   'external_url': 'https://api.spotify.com/v1/artists/3gIRvgZssIb9aiirIg0nI3'},
#  {'artist_id': '4gzpq5DPGxSnKTe4SA8HAU',
#   'artist_name': 'Coldplay',
#   'external_url': 'https://api.spotify.com/v1/artists/4gzpq5DPGxSnKTe4SA8HAU'},
#  {'artist_id': '246dkjvS1zLTtiykXe5h60',
#   'artist_name': 'Post Malone',
#   'external_url': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60'},
#  {'artist_id': '6eUKZXaKkcviH0Ku9w2n3V',
#   'artist_name': 'Ed Sheeran',
#   'external_url': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V'},
#  {'artist_id': '048LktY5zMnakWq7PTtFrz',
#   'artist_name': 'CKay',
#   'external_url': 'https://api.spotify.com/v1/artists/048LktY5zMnakWq7PTtFrz'},
#  {'artist_id': '4f7KfxeHq9BiylGmyXepGt',
#   'artist_name': 'Tanishk Bagchi',
#   'external_url': 'https://api.spotify.com/v1/artists/4f7KfxeHq9BiylGmyXepGt'},
#  {'artist_id': '1tqysapcCh1lWEAc9dIFpa',
#   'artist_name': 'Jubin Nautiyal',
#   'external_url': 'https://api.spotify.com/v1/artists/1tqysapcCh1lWEAc9dIFpa'},
#  {'artist_id': '1sVmXkzX2ukc6QvasrDBES',
#   'artist_name': 'Asees Kaur',
#   'external_url': 'https://api.spotify.com/v1/artists/1sVmXkzX2ukc6QvasrDBES'},
#  {'artist_id': '5ghnxpW47ojtLHHyTLdxdY',
#   'artist_name': 'Witt Lowry',
#   'external_url': 'https://api.spotify.com/v1/artists/5ghnxpW47ojtLHHyTLdxdY'},
#  {'artist_id': '4npEfmQ6YuiwW1GpUmaq3F',
#   'artist_name': 'Ava Max',
#   'external_url': 'https://api.spotify.com/v1/artists/4npEfmQ6YuiwW1GpUmaq3F'},
#  {'artist_id': '2tIP7SsRs7vjIcLrU85W8J',
#   'artist_name': 'The Kid LAROI',
#   'external_url': 'https://api.spotify.com/v1/artists/2tIP7SsRs7vjIcLrU85W8J'},
#  {'artist_id': '1uNFoZAHBGtllmzznpCI3s',
#   'artist_name': 'Justin Bieber',
#   'external_url': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s'}]

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                   name release_date  total_tracks  \
# 0  21dd5QyItuoqvPkViQXlKf  You Need To Calm Down   2019-06-14             1
# 1  2ZaX1FdZCwchXl1QZiD4O4               Señorita   2019-06-21             1
# 2  3KjXg0MDej2pG9fv6I22lT      Never Really Over   2019-05-31             1
# 3  0S9QJQiRmG9JYYfJfKqhDF    Illuminate (Deluxe)   2016-09-23            15
# 4  4vaaL8cnVy5KBJqbEPD8RF       Sugar & Brownies   2019-04-05             1
#
#                                                  url
# 0  https://open.spotify.com/album/21dd5QyItuoqvPk...
# 1  https://open.spotify.com/album/2ZaX1FdZCwchXl1...
# 2  https://open.spotify.com/album/3KjXg0MDej2pG9f...
# 3  https://open.spotify.com/album/0S9QJQiRmG9JYYf...
# 4  https://open.spotify.com/album/4vaaL8cnVy5KBJq...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id              song_name  duration_ms  \
# 0  29fRTIKsJhLUJoldM89GZS  You Need To Calm Down       171386
# 1  0TK2YIli7K1leLovkQiNik               Señorita       190960
# 2  5PYQUBXc7NYeI1obMKSJK0      Never Really Over       223523
# 3  76t5B0ttSAje5KHmQbv88t       Treat You Better       187973
# 4  4CAEINtapxGNYyjjJ1AKOA       Sugar & Brownies       197836
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/29fRTIKsJhLUJol...          18
# 1  https://open.spotify.com/track/0TK2YIli7K1leLo...          82
# 2  https://open.spotify.com/track/5PYQUBXc7NYeI1o...          71
# 3  https://open.spotify.com/track/76t5B0ttSAje5KH...           1
# 4  https://open.spotify.com/track/4CAEINtapxGNYyj...          67
#
#              song_added                album_id               artist_id
# 0  2019-06-16T02:55:39Z  21dd5QyItuoqvPkViQXlKf  06HL4z0CvFAxyc27GXpf02
# 1  2019-07-18T03:25:29Z  2ZaX1FdZCwchXl1QZiD4O4  7n2wHs1TKAczGzO7Dd2rGr
# 2  2019-07-18T03:25:41Z  3KjXg0MDej2pG9fv6I22lT  6jJ0s89eD6GaHleKKya26X
# 3  2019-09-22T04:15:31Z  0S9QJQiRmG9JYYfJfKqhDF  7n2wHs1TKAczGzO7Dd2rGr
# 4  2019-09-22T04:15:35Z  4vaaL8cnVy5KBJqbEPD8RF  1psakk7GVUl85AnTEvwtk2

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  06HL4z0CvFAxyc27GXpf02    Taylor Swift
# 1  7n2wHs1TKAczGzO7Dd2rGr    Shawn Mendes
# 2  4nDoRrQiYLoBzwC5BhVJzF  Camila Cabello
# 3  6jJ0s89eD6GaHleKKya26X      Katy Perry
# 5  1psakk7GVUl85AnTEvwtk2          DHARIA
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/06HL4z0CvFA...
# 1  https://api.spotify.com/v1/artists/7n2wHs1TKAc...
# 2  https://api.spotify.com/v1/artists/4nDoRrQiYLo...
# 3  https://api.spotify.com/v1/artists/6jJ0s89eD6G...
# 5  https://api.spotify.com/v1/artists/1psakk7GVUl...

# %%
album_df.head()
# Out:
#                  album_id                   name release_date  total_tracks  \
# 0  21dd5QyItuoqvPkViQXlKf  You Need To Calm Down   2019-06-14             1
# 1  2ZaX1FdZCwchXl1QZiD4O4               Señorita   2019-06-21             1
# 2  3KjXg0MDej2pG9fv6I22lT      Never Really Over   2019-05-31             1
# 3  0S9QJQiRmG9JYYfJfKqhDF    Illuminate (Deluxe)   2016-09-23            15
# 4  4vaaL8cnVy5KBJqbEPD8RF       Sugar & Brownies   2019-04-05             1
#
#                                                  url
# 0  https://open.spotify.com/album/21dd5QyItuoqvPk...
# 1  https://open.spotify.com/album/2ZaX1FdZCwchXl1...
# 2  https://open.spotify.com/album/3KjXg0MDej2pG9f...
# 3  https://open.spotify.com/album/0S9QJQiRmG9JYYf...
# 4  https://open.spotify.com/album/4vaaL8cnVy5KBJq...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'], errors='coerce')

# %%
album_df[album_df['release_date'].isna()]
# Out:
#                   album_id                                           name  \
# 5   2koMSm4dddvhxLzZyN2aEE
# 8   0kjXSwSLVipUi4lSEeF0yl                          All The Little Lights
# 32  7lF34sP6HtRAL7VEMvYHff
# 40  01gwy6CbJo0sNcKxzlZ9om
# 77  5ASFrellizlx98SmsItOEm
# 78  06l61IvDCVAeThVR8ajgxj
# 84  5FXIqS1XqbpfOKNoi5VUwS             See You Again (feat. Charlie Puth)
# 85  5NeG7Rk7ZUGVgvIRxPOmJ3  Troubadour (Champion Edition - Asian Version)
#
#    release_date  total_tracks  \
# 5           NaT             7
# 8           NaT            12
# 32          NaT             5
# 40          NaT             1
# 77          NaT             6
# 78          NaT            11
# 84          NaT             1
# 85          NaT            18
#
#                                                   url
# 5   https://open.spotify.com/album/2koMSm4dddvhxLz...
# 8   https://open.spotify.com/album/0kjXSwSLVipUi4l...
# 32  https://open.spotify.com/album/7lF34sP6HtRAL7V...
# 40  https://open.spotify.com/album/01gwy6CbJo0sNcK...
# 77  https://open.spotify.com/album/5ASFrellizlx98S...
# 78  https://open.spotify.com/album/06l61IvDCVAeThV...
# 84  https://open.spotify.com/album/5FXIqS1XqbpfOKN...
# 85  https://open.spotify.com/album/5NeG7Rk7ZUGVgvI...

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
